# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
# %matplotlib inline

# %matplotlib notebook

# %%
df = pd.read_csv('E:/.python and every thing/files/csv files/tehran_house.csv')
df
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# ...

# %%
# حذف مواردی که آدرس ندارند
# متراژ اشتباه وارد شده 
# نسخت باید ببینم کدوم ها هستند. ببینم 

# بعد منظور اشتباه را متوجه بشم یعنی چی ؟

# %%
# این میگه کل دیتا فریم خالی است
df.empty
# میگه غلطه یعنی دیتا فریم پره
# Out:
# False

# %%
# میگه کلا ایا ولیو های خالی داره یا نه 
df.isnull().values.any()
# Out:
# True

# %%
# این کل  دیتا فریم را برمرگردونه اونایی که خالی هستند را بده
df.isnull()
# Out:
#        Area   Room  Parking  Warehouse  Elevator  Address  Price  Price(USD)
# 0     False  False    False      False     False    False  False       False
# 1     False  False    False      False     False    False  False       False
# 2     False  False    False      False     False    False  False       False
# 3     False  False    False      False     False    False  False       False
# 4     False  False    False      False     False    False  False       False
# ...     ...    ...      ...        ...       ...      ...    ...         ...
# 3474  False  False    False      False     False    False  False       False
# 3475  False  False    False      False     False    False  False       False
# 3476  False  False    False      False     False    False  False       False
# 3477  False  False    False      False     False    False  False       False
# 3478  False  False    False      False     False    False  False       False
#
# [3479 rows x 8 columns]

# %%
# این ستون را میده . محدود میکنه
df['Area'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3474    False
# 3475    False
# 3476    False
# 3477    False
# 3478    False
# Name: Area, Length: 3479, dtype: bool

# %%
# میگه این دیتا فریم اصن خالی نداره 
df['Area'].isnull().values.any()
# Out:
# False

# %%
# یا باید بدونیم کدوم داره یا دونه دونه ستونه هار بیاریم

# %%
# میگه این داره 
df['Address'].isnull().values.any()
# Out:
# True

# %%
# این میگه ایا روی کدوم ستون ها هستش
df.isnull().any(axis=0)
# Out:
# Area          False
# Room          False
# Parking       False
# Warehouse     False
# Elevator      False
# Address        True
# Price         False
# Price(USD)    False
# dtype: bool

# %%
# این روی سطری که هست را میاره میگه

df.isnull().any(axis=1)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3474    False
# 3475    False
# 3476    False
# 3477    False
# 3478    False
# Length: 3479, dtype: bool

# %%
# کل دیتافریم را توصیف میکنه
df.describe

# معنی اینا رو نمیفهمم ایا فالس که زده چیه؟
# Out:
# <bound method NDFrame.describe of      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# ...

# %%
# این کل ستونها را میگه چندتا خالی داره
df.info()
# این میگه اون این تعداد پر داره 
# یعنی خالی پر هستند
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3479 entries, 0 to 3478
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Area        3479 non-null   object
#  1   Room        3479 non-null   int64
#  2   Parking     3479 non-null   bool
#  3   Warehouse   3479 non-null   bool
#  4   Elevator    3479 non-null   bool
#  5   Address     3456 non-null   object
#  6   Price       3479 non-null   float64
#  7   Price(USD)  3479 non-null   float64
# dtypes: bool(3), float64(2), int64(1), object(2)
# memory usage: 146.2+ KB

# %%
# این دیتا فریمهایی که خالی هستند را میده
df_nan=df[df.isnull().any(axis=1)]
df_nan
# Out:
#      Area  Room  Parking  Warehouse  Elevator Address         Price  \
# 43     60     2     True       True      True     NaN  2.650000e+09
# 662    85     2     True       True      True     NaN  1.955000e+09
# 706   117     2     True       True      True     NaN  6.500000e+09
# 1108   77     2     True       True     False     NaN  2.020000e+09
# 1109   71     1     True       True      True     NaN  2.300000e+09
# 1577  100     2     True       True      True     NaN  3.100000e+09
# 1796   70     2     True       True      True     NaN  4.830000e+09
# 2071   94     2     True       True      True     NaN  3.000000e+09
# 2072   99     2     True       True      True     NaN  4.150000e+09
# 2127   63     1     True       True     False     NaN  7.300000e+08
# 2243   62     2     True      False      True     NaN  1.440000e+09
# 2337   42     1    False       True     False     NaN  6.400000e+08
# 2426   65     1    False      False     False     NaN  6.500000e+08
# ...

# %%
# این اونایی که در اون ستون خالی هستند را میده
df[df['Address'].isnull()]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df[df['Address'].isnull()]
#
# NameError: name 'df' is not defined

# %%
# فیلتر کردن . اونایی که یکی
# nan
#  دارند را بده

# حالا اگر دوتا بود 
# دو میدادیم
df.iloc[df[(df.isnull().sum(axis=1) >= 1)].index]
# اون سطر هایی که در یک ستون نن دارد
# Out:
#      Area  Room  Parking  Warehouse  Elevator Address         Price  \
# 43     60     2     True       True      True     NaN  2.650000e+09
# 662    85     2     True       True      True     NaN  1.955000e+09
# 706   117     2     True       True      True     NaN  6.500000e+09
# 1108   77     2     True       True     False     NaN  2.020000e+09
# 1109   71     1     True       True      True     NaN  2.300000e+09
# 1577  100     2     True       True      True     NaN  3.100000e+09
# 1796   70     2     True       True      True     NaN  4.830000e+09
# 2071   94     2     True       True      True     NaN  3.000000e+09
# 2072   99     2     True       True      True     NaN  4.150000e+09
# 2127   63     1     True       True     False     NaN  7.300000e+08
# 2243   62     2     True      False      True     NaN  1.440000e+09
# 2337   42     1    False       True     False     NaN  6.400000e+08
# 2426   65     1    False      False     False     NaN  6.500000e+08
# ...

# %%
# اون سطری که خالی نیست را میده
df_not=df[df['Address'].notnull()]
df_not
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# ...

# %%
# حالا اگر همه ستون ها یا چند تا ستون خالی داشتند کل سطرشونو حذف میکردیم؟
df_not=df[df.notnull()]
df_not
# این کلشو میاره
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# ...

# %%
# فقط سطر ۴۳ را میده
print(df.loc[[43]])

# %%
# تعدادشون که خالی است
df['Address'].isna().sum()

# %%
# تعداد کل هم اینه
len(df. index)

# %%
# تعدادی که پس از خالی شدن باید باشه

len(df. index) - df['Address'].isna().sum()

# %%
df_not=df.notnull()
df_not
# اینم کلشو میاره 
# من میخوام بگم همه اونایی که سطر خالی دارند در هر ستونی
# Out:
#       Area  Room  Parking  Warehouse  Elevator  Address  Price  Price(USD)
# 0     True  True     True       True      True     True   True        True
# 1     True  True     True       True      True     True   True        True
# 2     True  True     True       True      True     True   True        True
# 3     True  True     True       True      True     True   True        True
# 4     True  True     True       True      True     True   True        True
# ...    ...   ...      ...        ...       ...      ...    ...         ...
# 3474  True  True     True       True      True     True   True        True
# 3475  True  True     True       True      True     True   True        True
# 3476  True  True     True       True      True     True   True        True
# 3477  True  True     True       True      True     True   True        True
# 3478  True  True     True       True      True     True   True        True
#
# [3479 rows x 8 columns]

# %%
filtered_df = df[df[['Address', 'Warehouse', 'Area']].notnull().all(1)]
filtered_df

# این اون کار را میکنه ولی انگار باید همه ستون هاشو بهش بدی .
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# ...

# %%
# نفهمیدم چکار میکنه
df.dropna(thresh=1)
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# ...

# %%
# گام بعدیم اینه که بیام  متراژ ها را درست کنم
# اما مگه متراژها چشونه 
# اول باید بفهمم . باید برای این ببینمشون و بررسی کنم

# %%
# دیتا درست شدمون اینه
df_non_filter = df[df[['Address', 'Warehouse', 'Area']].notnull().all(1)]
df_non_filter
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# ...

# %%
# انواع داده هایی که داره را بده
df.Area.unique()

# %%
# اونایی که ۳۰ دارند را نشون میده
df[df['Area'].astype(str).str.contains('30')]

# %%
# اونایی که , دارند را نشون میده
df[df['Area'].astype(str).str.contains(',')]

# %%
# اونا که هر ددو را دارند
df[df['A'].astype(str).str.contains("Hello|Britain")]

# %%
# اونایی که چیزی را ندارند
# فیلتر کردن 
df[~df['Area'].astype(str).str.contains(',')]

# %%
df_non_filter['Area']
# Out:
# 0        63
# 1        60
# 2        79
# 3        95
# 4       123
#        ...
# 3474     86
# 3475     83
# 3476     75
# 3477    105
# 3478     82
# Name: Area, Length: 3456, dtype: object

# %%
# این همه مقدار های یه ستون را میده بهمون
df_non_filter['Area'].tolist()
# Out:
# ['63',
#  '60',
#  '79',
#  '95',
#  '123',
#  '70',
#  '87',
#  '59',
#  '54',
#  '71',
#  '68',
#  '64',
#  '54',
#  '136',
#  '95',
#  '63',
#  '155',
#  '64',
#  '140',
#  '42',
#  '93',
#  '87',
#  '65',
#  '99',
#  '105',
#  '160',
#  '77',
#  '123',
#  '110',
#  '100',
#  '90',
#  '49',
#  '96',
#  '67',
#  '68',
#  '62',
#  '55',
#  '110',
#  '129',
#  '109',
#  '58',
#  '55',
#  '150',
#  '130',
#  '88',
#  '51',
#  '113',
#  '110',
#  '60',
#  '98',
#  '62',
#  '150',
#  '75',
#  '61',
#  '61',
#  '72',
#  '100',
#  '122',
#  '215',
#  '101',
#  '67',
#  '72',
#  '63',
#  '75',
#  '109',
#  '122',
#  '70',
#  '60',
#  '53',
#  '90',
#  '72',
#  '74',
#  '88',
#  '63',
#  '114',
#  '151',
#  '42',
#  '74',
#  '88',
#  '63',
#  '114',
#  '151',
#  '42',
#  '300',
#  '110',
#  '100',
#  '140',
#  '70',
#  '60',
#  '76',
#  '148',
#  '75',
#  '40',
#  '65',
#  '140',
#  '110',
#  '70',
#  '128',
#  '94',
#  '67',
#  '75',
#  '130',
#  '40',
#  '97',
#  '110',
#  '150',
# ...

# %%
# بررسی که چیزی در دیتا فریم است یا خیر؟
' 2,550,000,000 '  in df
# اینو به غلط میده FALSE

# %%
# این همه ولیو ها را میده  در یک لیست
for i in list(df):
    # show the list of values  
    print(df[i].tolist())
# Out:
# ['63', '60', '79', '95', '123', '70', '87', '59', '54', '71', '68', '64', '54', '136', '95', '63', '155', '64', '140', '42', '93', '87', '65', '99', '105', '160', '77', '123', '110', '100', '90', '49', '96', '67', '68', '62', '55', '110', '129', '109', '58', '55', '150', '60', '130', '88', '51', '113', '110', '60', '98', '62', '150', '75', '61', '61', '72', '100', '122', '215', '101', '67', '72', '63', '75', '109', '122', '70', '60', '53', '90', '72', '74', '88', '63', '114', '151', '42', '74', '88', '63', '114', '151', '42', '300', '110', '100', '140', '70', '60', '76', '148', '75', '40', '65', '140', '110', '70', '128', '94', '67', '75', '130', '40', '97', '110', '150', '75', '137', '85', '68', '78', '85', '100', '71', '140', '136', '48', '100', '82', '120', '139', '110', '78', '79', '66', '78', '85', '100', '80', '44', '120', '50', '121', '80', '70', '160', '40', '88', '141', '140', '120', '66', '70', '75', '70', '150', '95', '127', '123', '63', '90', '105', '180', '120', '65', '1
# ...

# %%
# این فقط سر ستون هاشو میده
list(df)
# Out:
# ['Area',
#  'Room',
#  'Parking',
#  'Warehouse',
#  'Elevator',
#  'Address',
#  'Price',
#  'Price(USD)']

# %%
# این دونه دونه ستون هارا میاره و توصیف میکنه و بخشیشو میده
for i in list(df):
    # show the list of values  
    print(df[i])
# Out:
# 0        63
# 1        60
# 2        79
# 3        95
# 4       123
#        ...
# 3474     86
# 3475     83
# 3476     75
# 3477    105
# 3478     82
# Name: Area, Length: 3479, dtype: object
# 0       1
# 1       1
# 2       2
# 3       2
# 4       2
#        ..
# 3474    2
# 3475    2
# 3476    2
# 3477    2
# 3478    2
# Name: Room, Length: 3479, dtype: int64
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 3474     True
# 3475     True
# 3476    False
# 3477     True
# 3478    False
# Name: Parking, Length: 3479, dtype: bool
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 3474     True
# 3475     True
# 3476    False
# 3477     True
# 3478     True
# Name: Warehouse, Length: 3479, dtype: bool
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 3474     True
# 3475     True
# 3476    False
# 3477     True
# 3478     True
# ...

# %%
# این نشد فیلتر کنه 
slots = df_non_filter[df_non_filter['Area'].between('50', '1000')]
slots
# Out:
# Empty DataFrame
# Columns: [Area, Room, Parking, Warehouse, Elevator, Address, Price, Price(USD)]
# Index: []

# %%
df_non_filter['Area'].between('50', '1000')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3474    False
# 3475    False
# 3476    False
# 3477    False
# 3478    False
# Name: Area, Length: 3456, dtype: bool

# %%
df_non_filter[df_non_filter['Area'].between('50', '1000')]
# Out:
# Empty DataFrame
# Columns: [Area, Room, Parking, Warehouse, Elevator, Address, Price, Price(USD)]
# Index: []

# %%
# این ایندکسشو فیلتر میکنه یعنی از ایندکس ۲۰۰ تا ۱۰۰۰ را بده 
df['Area'].loc[200:1000]

# اینم کل دیتا فریم را فیلتر میکنه از روی ایندکس نه ولیو
df.loc[200:1000]
# Out:
#      Area  Room  Parking  Warehouse  Elevator                    Address  \
# 200    83     2     True       True      True                   Republic
# 201   270     4     True       True      True                  Farmanieh
# 202   104     2     True       True      True     East Ferdows Boulevard
# 203   150     3     True       True      True                 Zaferanieh
# 204   103     3     True       True      True     West Ferdows Boulevard
# ...   ...   ...      ...        ...       ...                        ...
# 996   107     2     True       True      True  Persian Gulf Martyrs Lake
# 997   113     2     True       True      True  Persian Gulf Martyrs Lake
# 998   115     2     True       True      True                 Gheitarieh
# 999   115     2     True       True      True  Persian Gulf Martyrs Lake
# 1000  120     2     True       True      True                    Gholhak
#
#              Price  Price(USD)
# 200   1.909000e+09    63633.33
# ...

# %%
# این کار نمیکنه
df[(df['Area'] > '200') & (df['Area'] < '1000')]

# قاعتا باید بگه هم مساحت های بیشتر از ۲۰۰ و هم کمتر از هزار 
# انتظارم اینه که بین ۲۰۰ تا هزار را بیاره واسمون
# Out:
# Empty DataFrame
# Columns: [Area, Room, Parking, Warehouse, Elevator, Address, Price, Price(USD)]
# Index: []

# %%
# ولی برای این یه چیزهایی را میاره . منتها انگار فیلتر نکرده چون ۶۰ متری هم اورده
df[(df['Area'] > '200') | (df['Area'] < '1000')]
# ولی وقتی بجای ۲۰۰ میزارم ۱۰۰ اون ۱۵۰ متری را هم میاره
# ولی مساله اینه که ۶۰را اورد . ایا بخاطر یا نیست ؟
# Out:
#      Area  Room  Parking  Warehouse  Elevator                     Address  \
# 0      63     1     True       True      True                     Shahran
# 1      60     1     True       True      True                     Shahran
# 2      79     2     True       True      True                      Pardis
# 3      95     2     True       True      True               Shahrake Qods
# 5      70     2     True       True     False  North Program Organization
# ...   ...   ...      ...        ...       ...                         ...
# 3473   63     1     True       True     False                 Feiz Garden
# 3474   86     2     True       True      True          Southern Janatabad
# 3475   83     2     True       True      True                    Niavaran
# 3476   75     2    False      False     False                      Parand
# 3478   82     2    False       True      True                      Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# ...

# %%
df[(df['Area'] > '100') & (df['Area'] < '100')]
df
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# ...

# %%
# این اونایی که فقط صد متر هستند را میده . اون سطر هایی که مساحتشون ۱۰۰ است
df2=df[df["Area"] == '100'] 
print(df2)
# Out:
#      Area  Room  Parking  Warehouse  Elevator                 Address  \
# 29    100     2     True       True      True  West Ferdows Boulevard
# 57    100     2     True       True      True           Qasr-od-Dasht
# 86    100     2    False      False     False           Shahrake Qods
# 113   100     2     True       True     False                  Parand
# 118   100     2     True       True      True                 Lavizan
# ...   ...   ...      ...        ...       ...                     ...
# 3054  100     2     True       True     False            Shahr-e-Ziba
# 3137  100     2     True       True      True      Southern Janatabad
# 3219  100     2     True       True      True                 Shahran
# 3407  100     2     True       True      True             Saadat Abad
# 3412  100     2     True       True      True             Saadat Abad
#
#              Price  Price(USD)
# 29    3.200000e+09   106666.67
# 57    3.000000e+09   100000.00
# ...

# %%
df[df["Area"] == '100'] 
# اینم دیتا فریم100 را میده 
# print(df2)
# Out:
#      Area  Room  Parking  Warehouse  Elevator                 Address  \
# 29    100     2     True       True      True  West Ferdows Boulevard
# 57    100     2     True       True      True           Qasr-od-Dasht
# 86    100     2    False      False     False           Shahrake Qods
# 113   100     2     True       True     False                  Parand
# 118   100     2     True       True      True                 Lavizan
# ...   ...   ...      ...        ...       ...                     ...
# 3054  100     2     True       True     False            Shahr-e-Ziba
# 3137  100     2     True       True      True      Southern Janatabad
# 3219  100     2     True       True      True                 Shahran
# 3407  100     2     True       True      True             Saadat Abad
# 3412  100     2     True       True      True             Saadat Abad
#
#              Price  Price(USD)
# 29    3.200000e+09   106666.67
# 57    3.000000e+09   100000.00
# ...

# %%
# انگار این فقط اونا که بزرگتر هستند را میده
df[df["Area"] < '10'] 
# ولی فقط ۵ تا داد
# Out:
#                   Area  Room  Parking  Warehouse  Elevator            Address  \
# 570     3,310,000,000      2     True       True      True        Ostad Moein
# 709    16,160,000,000      3     True       True      True           Pasdaran
# 807             1,000      2     True       True     False           Damavand
# 1604    8,400,000,000      2     True       True      True         Gheitarieh
# 2171            3,600      2    False      False     False           Shahryar
# 2802    2,550,000,000      2     True       True      True  Central Janatabad
#
#              Price  Price(USD)
# 570   3.310000e+09   110333.33
# 709   1.616000e+10   538666.67
# 807   7.000000e+09   233333.33
# 1604  8.700000e+09   290000.00
# 2171  9.720000e+09   324000.00
# 2802  2.550000e+09    85000.00

# %%
# این حالا 110 تا را داده 
df[df["Area"] < '1000']
# Out:
#      Area  Room  Parking  Warehouse  Elevator                 Address  \
# 29    100     2     True       True      True  West Ferdows Boulevard
# 57    100     2     True       True      True           Qasr-od-Dasht
# 86    100     2    False      False     False           Shahrake Qods
# 113   100     2     True       True     False                  Parand
# 118   100     2     True       True      True                 Lavizan
# ...   ...   ...      ...        ...       ...                     ...
# 3054  100     2     True       True     False            Shahr-e-Ziba
# 3137  100     2     True       True      True      Southern Janatabad
# 3219  100     2     True       True      True                 Shahran
# 3407  100     2     True       True      True             Saadat Abad
# 3412  100     2     True       True      True             Saadat Abad
#
#              Price  Price(USD)
# 29    3.200000e+09   106666.67
# 57    3.000000e+09   100000.00
# ...

# %%
# اینم همون تعداد را میده ۱۱۰
df[df["Area"] < '100000000']
# Out:
#      Area  Room  Parking  Warehouse  Elevator                 Address  \
# 29    100     2     True       True      True  West Ferdows Boulevard
# 57    100     2     True       True      True           Qasr-od-Dasht
# 86    100     2    False      False     False           Shahrake Qods
# 113   100     2     True       True     False                  Parand
# 118   100     2     True       True      True                 Lavizan
# ...   ...   ...      ...        ...       ...                     ...
# 3054  100     2     True       True     False            Shahr-e-Ziba
# 3137  100     2     True       True      True      Southern Janatabad
# 3219  100     2     True       True      True                 Shahran
# 3407  100     2     True       True      True             Saadat Abad
# 3412  100     2     True       True      True             Saadat Abad
#
#              Price  Price(USD)
# 29    3.200000e+09   106666.67
# 57    3.000000e+09   100000.00
# ...

# %%
# اینم اینو میده 
df[df["Area"] >'10000000'] 
# در صورتی که من میخوام بگم اونایی که بزرگتر از۱۰۰۰  هست را نده  
# ولی میده
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# ...

# %%
df[df["Warehouse"] =='False'] 
# این هیچی نمیده  ولی قاعدتا باید بده
# Out:
# Empty DataFrame
# Columns: [Area, Room, Parking, Warehouse, Elevator, Address, Price, Price(USD)]
# Index: []

# %%
# این اون موارد را میده به گمونم که فالس هست
[df["Warehouse"] =='False']
# Out:
# [0       False
#  1       False
#  2       False
#  3       False
#  4       False
#          ...
#  3474    False
#  3475    False
#  3476    False
#  3477    False
#  3478    False
#  Name: Warehouse, Length: 3479, dtype: bool]

# %%
# حتما میشه دو تا قیف گذاشت
# روی دو تا ستون
# متغیرهاشون اینجوریه
df[(df['Area'] == '100') & (df['Address']=='Saadat Abad')    ]
# Out:
#      Area  Room  Parking  Warehouse  Elevator      Address         Price  \
# 2001  100     2     True       True      True  Saadat Abad  6.500000e+09
# 2023  100     2     True       True      True  Saadat Abad  7.400000e+09
# 2062  100     2     True       True      True  Saadat Abad  6.000000e+09
# 3407  100     2     True       True      True  Saadat Abad  4.550000e+09
# 3412  100     2     True       True      True  Saadat Abad  4.480000e+09
#
#       Price(USD)
# 2001   216666.67
# 2023   246666.67
# 2062   200000.00
# 3407   151666.67
# 3412   149333.33

# %%
# این هم کوچکترهارو میده هم بزرگتر ها را
df[(df['Area'] > '100')]
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# ...

# %%
df[(df['Area'] < '20')  ]
# Out:
#      Area  Room  Parking  Warehouse  Elevator                 Address  \
# 4     123     2     True       True      True          Shahrake Gharb
# 13    136     3     True       True      True             Saadat Abad
# 16    155     3     True       True      True                  Narmak
# 18    140     3     True       True      True  West Ferdows Boulevard
# 24    105     2     True       True      True             Saadat Abad
# ...   ...   ...      ...        ...       ...                     ...
# 3457  123     3     True       True      True                Velenjak
# 3458  148     3     True       True      True               Daryan No
# 3463  133     3     True      False      True          Shahrake Gharb
# 3472  113     3     True       True      True             Ostad Moein
# 3477  105     2     True       True      True                  Dorous
#
#              Price  Price(USD)
# 4     7.000000e+09   233333.33
# 13    1.100000e+10   366666.67
# ...

# %%
# روش دیگر اینه
# آهان
# ولی یه مساله اینکه کوچکتر از ۱۰ اینها را داده 
# یعنی انگار اینها که عددشونو مثل پول داده این مشکل را میارن
one_year_loc = df.loc[lambda x: x["Area"] <= '10']

one_year_loc
# Out:
#                   Area  Room  Parking  Warehouse  Elevator            Address  \
# 570     3,310,000,000      2     True       True      True        Ostad Moein
# 709    16,160,000,000      3     True       True      True           Pasdaran
# 807             1,000      2     True       True     False           Damavand
# 1604    8,400,000,000      2     True       True      True         Gheitarieh
# 2171            3,600      2    False      False     False           Shahryar
# 2802    2,550,000,000      2     True       True      True  Central Janatabad
#
#              Price  Price(USD)
# 570   3.310000e+09   110333.33
# 709   1.616000e+10   538666.67
# 807   7.000000e+09   233333.33
# 1604  8.700000e+09   290000.00
# 2171  9.720000e+09   324000.00
# 2802  2.550000e+09    85000.00

# %%
# پس منطق درسته 
# اونها را میگیم بهمون بده . تحویل بده میده  مثلا اگر ۱۰۰ بزاریم 
one_year_loc = df.loc[lambda x: x["Area"] <= '100']
# اون ۱۰۰ متری ها هم میده 
one_year_loc

# اونا که کمتر یا مساوی۱۰۰ هستند را بگو
# Out:
#      Area  Room  Parking  Warehouse  Elevator                 Address  \
# 29    100     2     True       True      True  West Ferdows Boulevard
# 57    100     2     True       True      True           Qasr-od-Dasht
# 86    100     2    False      False     False           Shahrake Qods
# 113   100     2     True       True     False                  Parand
# 118   100     2     True       True      True                 Lavizan
# ...   ...   ...      ...        ...       ...                     ...
# 3054  100     2     True       True     False            Shahr-e-Ziba
# 3137  100     2     True       True      True      Southern Janatabad
# 3219  100     2     True       True      True                 Shahran
# 3407  100     2     True       True      True             Saadat Abad
# 3412  100     2     True       True      True             Saadat Abad
#
#              Price  Price(USD)
# 29    3.200000e+09   106666.67
# 57    3.000000e+09   100000.00
# ...

# %%
# که اگر بزرگتر بزنی تبعا نمیاره دیگه
one_year_loc = df.loc[lambda x: x["Area"] >= '1000']
one_year_loc

# پس چرا اینو میاره؟
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# ...

# %%
# ولی چرا اونا که کمتر از ۱۰۰ هستند نمیاره ۶۰ متری را؟
one_year_loc = df.loc[lambda x: x["Area"] < '100']
# اون ۱۰۰ متری ها هم میده 
one_year_loc

# ?????????????
# Out:
#                   Area  Room  Parking  Warehouse  Elevator            Address  \
# 570     3,310,000,000      2     True       True      True        Ostad Moein
# 709    16,160,000,000      3     True       True      True           Pasdaran
# 807             1,000      2     True       True     False           Damavand
# 1604    8,400,000,000      2     True       True      True         Gheitarieh
# 2171            3,600      2    False      False     False           Shahryar
# 2802    2,550,000,000      2     True       True      True  Central Janatabad
#
#              Price  Price(USD)
# 570   3.310000e+09   110333.33
# 709   1.616000e+10   538666.67
# 807   7.000000e+09   233333.33
# 1604  8.700000e+09   290000.00
# 2171  9.720000e+09   324000.00
# 2802  2.550000e+09    85000.00

# %%
# حالا که میگیم کمتر از پنجا اینها را میاره
one_year_loc = df.loc[lambda x: x["Area"] < '50']
one_year_loc
# Out:
#      Area  Room  Parking  Warehouse  Elevator                 Address  \
# 4     123     2     True       True      True          Shahrake Gharb
# 13    136     3     True       True      True             Saadat Abad
# 16    155     3     True       True      True                  Narmak
# 18    140     3     True       True      True  West Ferdows Boulevard
# 19     42     1    False       True     False                 Pirouzi
# ...   ...   ...      ...        ...       ...                     ...
# 3457  123     3     True       True      True                Velenjak
# 3458  148     3     True       True      True               Daryan No
# 3463  133     3     True      False      True          Shahrake Gharb
# 3472  113     3     True       True      True             Ostad Moein
# 3477  105     2     True       True      True                  Dorous
#
#              Price  Price(USD)
# 4     7.000000e+09   233333.33
# 13    1.100000e+10   366666.67
# ...

# %%
# این فقط ستون را میده 
df[['Area']]
# Out:
#      Area
# 0      63
# 1      60
# 2      79
# 3      95
# 4     123
# ...   ...
# 3474   86
# 3475   83
# 3476   75
# 3477  105
# 3478   82
#
# [3479 rows x 1 columns]

# %%
df[['Area']<'50']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df[['Area']<'50']
#
# TypeError: '<' not supported between instances of 'list' and 'str'

# %%
# اونایی که بزرگتر از ۵۰ هستند را میده به گمونم
df[df['Area'] > '50']

# ولی اینم مشکل داره

# %%
a= df[df['Area'] > '50']
a['Area'].tolist()

# %%
df1 = pd.read_csv('E:/.python and every thing/files/csv files/tehran_house.csv')
my= df1[df1['Area']>='200']
my['Area'].tolist()
# چرا این میره هم ۶۰ را میاره و هم ۴۰۰ را  ؟ مشکل کجاست؟

# %%
my= df1[df1['Area']<='200']
my['Area'].tolist()
# انگار این بهتره و فقط کوچکتر از ۲۰۰ ها را داده 
# به غیر از اینکه اون چند رقمی ها را زیر ده میشناسه

# %%
my

# %%
# اینم همنو داده 
# متغیر تعریف میکنیم  قبلش
msk=df1.loc[(df1['Area'] >= '10') | (df1['Area'] <= '2000')  ]
msk

# اصن هیچ فیلتری نگذاشته
# این بازهم ۳۶۰۰۰۰ را میده

# %%
msk['Area'].tolist()

# %%
msk=df1.loc[(df1['Area'] >= '10') & (df1['Area'] <= '2000')  ]
msk

# این داده ها را بیشتر از هار تا کم کرده

# %%
msk['Area'].tolist()

# %%
# اصن چطور بفهمم که اون عدد ها هستند یا نه ؟
' 1,000 '
 ' 3,310,000,000 ',
 ' 16,160,000,000 ',
 ' 1,000 ',

# %%
# حذف مواردی که اینو داشته باشند
drop_df= df[df['Area'].astype(str).str.contains(',')]
df = df.drop(drop_df.index, axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 drop_df= df[df['Area'].astype(str).str.contains(',')]
#       2 df = df.drop(drop_df.index, axis=0)
#
# NameError: name 'df' is not defined

# %%
# یه چیز دیگه 
# ایده 
# اینا قیمت هاشونه که اومده . پس میشه بررسی کنم اونایی که قیمتشون با پرایس یکی بود اونها را فیلتر کن دیگه 
# مگر اینکه یه قیمت درست باشه . مثلا ۱۰۰ متری ۱۰۰ تا تک تومن بود؟ مسخره است



# اینکه ایا همه داده های پرت دقیقا همون ها هستند ؟
# یعنی ممکن نیست از یه جا دیگه داده باشه ؟


# ایا داده های پرت را میشه دسته بندی کرد؟
# در اون صورت میشه گفت بله اونا که چرت هستند همشون یه جوری اند و همه اونجوری ها را وارد نکن


# چطوره استریپ کنیم اول  همه عدد هارا

# همشون اعشار دارند . با اون میشه

# %%
df[df["Area"] < '100']
# Out:
#                   Area  Room  Parking  Warehouse  Elevator            Address  \
# 570     3,310,000,000      2     True       True      True        Ostad Moein
# 709    16,160,000,000      3     True       True      True           Pasdaran
# 807             1,000      2     True       True     False           Damavand
# 1604    8,400,000,000      2     True       True      True         Gheitarieh
# 2171            3,600      2    False      False     False           Shahryar
# 2802    2,550,000,000      2     True       True      True  Central Janatabad
#
#              Price  Price(USD)
# 570   3.310000e+09   110333.33
# 709   1.616000e+10   538666.67
# 807   7.000000e+09   233333.33
# 1604  8.700000e+09   290000.00
# 2171  9.720000e+09   324000.00
# 2802  2.550000e+09    85000.00

# %%
df

# %%
# این کل یه ستون را فیلتر میکنه 
df.loc[:, df.columns != 'Elevator']
# Out:
#      Area  Room  Parking  Warehouse             Address         Price  \
# 0      63     1     True       True             Shahran  1.850000e+09
# 1      60     1     True       True             Shahran  1.850000e+09
# 2      79     2     True       True              Pardis  5.500000e+08
# 3      95     2     True       True       Shahrake Qods  9.025000e+08
# 4     123     2     True       True      Shahrake Gharb  7.000000e+09
# ...   ...   ...      ...        ...                 ...           ...
# 3474   86     2     True       True  Southern Janatabad  3.500000e+09
# 3475   83     2     True       True            Niavaran  6.800000e+09
# 3476   75     2    False      False              Parand  3.650000e+08
# 3477  105     2     True       True              Dorous  5.600000e+09
# 3478   82     2    False       True              Parand  3.600000e+08
#
#       Price(USD)
# 0       61666.67
# 1       61666.67
# 2       18333.33
# 3       30083.33
# 4      233333.33
# ...

# %%
# اینم یه ستون را برمیداره
df.drop('Area', axis=1)
# Out:
#       Room  Parking  Warehouse  Elevator             Address         Price  \
# 0        1     True       True      True             Shahran  1.850000e+09
# 1        1     True       True      True             Shahran  1.850000e+09
# 2        2     True       True      True              Pardis  5.500000e+08
# 3        2     True       True      True       Shahrake Qods  9.025000e+08
# 4        2     True       True      True      Shahrake Gharb  7.000000e+09
# ...    ...      ...        ...       ...                 ...           ...
# 3474     2     True       True      True  Southern Janatabad  3.500000e+09
# 3475     2     True       True      True            Niavaran  6.800000e+09
# 3476     2    False      False     False              Parand  3.650000e+08
# 3477     2     True       True      True              Dorous  5.600000e+09
# 3478     2    False       True      True              Parand  3.600000e+08
#
#       Price(USD)
# 0       61666.67
# 1       61666.67
# ...

# %%
df

# %%
# این میاد اون سطری که اینو داره را حذف میکنه 
df[~(df['Area'] == ' 3,310,000,000 ')]
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# ...

# %%
# حالا چطور چند تا را بهش بدم؟
# ' 1,000 '
#  ' 3,310,000,000 ',
#  ' 16,160,000,000 ',
#  ' 1,000 ',
df[~(df['Area']==' 3,310,000,000 ' |' 1,000 ')]   

# این کار نمیکنه
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 6
#       1 # حالا چطور چند تا را بهش بدم؟
#       2 # ' 1,000 '
#       3 #  ' 3,310,000,000 ',
#       4 #  ' 16,160,000,000 ',
#       5 #  ' 1,000 ',
# ----> 6 df[~(df['Area']==' 3,310,000,000 ' |' 1,000 ')]
#       8 # این کار نمیکنه
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'

# %%
# ' 1,000 '
#  ' 3,310,000,000 ',
#  ' 16,160,000,000 ',
#  ' 1,000 ',
df[~(df['Area']==' 3,310,000,000 ' &df['Area']==' 1,000 ')]   
df[~(df['Area']==' 3,310,000,000 ' |df['Area']==' 1,000 ')]   

# این دو تا هم نمیشه
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\ops\array_ops.py:305, in na_logical_op(x, y, op)
#     296 try:
#     297     # For exposition, write:
#     298     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     303     # Then Cases where this goes through without raising include:
#     304     #  (xint or xbool) and (yint or bool)
# --> 305     result = op(x, y)
#     306 except TypeError:
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\pandas\core\roperator.py:54, in rand_(left, right)
#      53 def rand_(left, right):
# ---> 54     return operator.and_(right, left)
#
# TypeError: unsupported operand type(s) for &: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# این اصلا تاثیری نداره . یعنی هیچ کدومو انجام نمیده
df = df[~ ((df['Area']==' 3,310,000,000 ') & (df['Area']==' 1,000 ')) ] 
df
# ۳۴۷۹ تعداد دیتا فریم بود الانم همینه
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# ...

# %%
# این کار کرد. تعدادشو کم کرد
df = df[~ ((df['Area']==' 3,310,000,000 ') | (df['Area']==' 1,000 ')) ] 
df

# مشکل داره . ما دونه دونه برای اعداد باید اینو بدیم ؟
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# ...

# %%
# ایا میشه تایپ بدیم؟

df = df[~ ((df['Area']==astype(int)) ) ] 
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 3
#       1 # ایا میشه تایپ بدیم؟
# ----> 3 df = df[~ ((df['Area']==astype(int)) ) ]
#       4 df
#
# NameError: name 'astype' is not defined

# %%
# این بهتر است . چون خلاصه تره 

df2 = df[~(df['Area'].isin([' 3,310,000,000 ',' 1,000 ']))]
df2
# ولی همون مشکل را داره . دونه دونه اعدادمونو باید پیدا کنیم بهش بگیم؟
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# ...

# %%
 ' 3,310,000,000 ',
 ' 16,160,000,000 ',
 ' 1,000 ',
df2 = df[~(df['Area'].isin([' 3,310,000,000 ',' 16,160,000,000 ',' 1,000 ',' 2,000 ']))]
df2
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# ...

# %%
df2['Area'].tolist()
# Out:
# ['63',
#  '60',
#  '79',
#  '95',
#  '123',
#  '70',
#  '87',
#  '59',
#  '54',
#  '71',
#  '68',
#  '64',
#  '54',
#  '136',
#  '95',
#  '63',
#  '155',
#  '64',
#  '140',
#  '42',
#  '93',
#  '87',
#  '65',
#  '99',
#  '105',
#  '160',
#  '77',
#  '123',
#  '110',
#  '100',
#  '90',
#  '49',
#  '96',
#  '67',
#  '68',
#  '62',
#  '55',
#  '110',
#  '129',
#  '109',
#  '58',
#  '55',
#  '150',
#  '60',
#  '130',
#  '88',
#  '51',
#  '113',
#  '110',
#  '60',
#  '98',
#  '62',
#  '150',
#  '75',
#  '61',
#  '61',
#  '72',
#  '100',
#  '122',
#  '215',
#  '101',
#  '67',
#  '72',
#  '63',
#  '75',
#  '109',
#  '122',
#  '70',
#  '60',
#  '53',
#  '90',
#  '72',
#  '74',
#  '88',
#  '63',
#  '114',
#  '151',
#  '42',
#  '74',
#  '88',
#  '63',
#  '114',
#  '151',
#  '42',
#  '300',
#  '110',
#  '100',
#  '140',
#  '70',
#  '60',
#  '76',
#  '148',
#  '75',
#  '40',
#  '65',
#  '140',
#  '110',
#  '70',
#  '128',
#  '94',
#  '67',
#  '75',
#  '130',
#  '40',
#  '97',
#  '110',
# ...

# %%
df=df2[df2['Address'].notnull()]
df
# Out:
#      Area  Room  Parking  Warehouse  Elevator             Address  \
# 0      63     1     True       True      True             Shahran
# 1      60     1     True       True      True             Shahran
# 2      79     2     True       True      True              Pardis
# 3      95     2     True       True      True       Shahrake Qods
# 4     123     2     True       True      True      Shahrake Gharb
# ...   ...   ...      ...        ...       ...                 ...
# 3474   86     2     True       True      True  Southern Janatabad
# 3475   83     2     True       True      True            Niavaran
# 3476   75     2    False      False     False              Parand
# 3477  105     2     True       True      True              Dorous
# 3478   82     2    False       True      True              Parand
#
#              Price  Price(USD)
# 0     1.850000e+09    61666.67
# 1     1.850000e+09    61666.67
# 2     5.500000e+08    18333.33
# 3     9.025000e+08    30083.33
# ...

# %%
# آیا بین مساحت و قیمت رابطه ای هست؟ 
plt.scatter(df['Area'],df['Price'])
plt.show()

# چجوری باید کشش بدم که بیاد همه را نشون بده؟

# %%
# اینم بزرگ کردم نشد
plt.scatter(df['Area'],df['Price'])
plt.figure(figsize=(28,16))
plt.show()

# %%
plt.scatter(df['Area'],df['Price'])
plt.show()

# %%
# فقط رابطه دلار و قیمت این معنا را داره

plt.scatter(df['Price(USD)'],df['Price'])
plt.show()

# %%
# رابطه بین نشانی و قیمت
plt.scatter(df['Address'],df['Price'])
plt.show()

# %%
# Room
plt.scatter(df['Room'],df['Price'])
plt.show()

# %%
# انگار چند تا عامل هست که با هم ایکسشون میشه و ایگیریگشون میاد

# %%
# تغیر داده ها

# گاهی این میزان دقت را بطه را میده 
np.corrcoef(df['Area'], df['Price'])
# جواب نمیده 
# یه احتمال اینه که دیتا تایپش فرق داره

# %%
# نوع همه را میده
df.dtypes

# %%
# دیدن تایپ ستون اسانسور
df.Elevator.dtypes

# %%
# یه روش اینه
# خودکار همشونو تبدیل میکنه به بهترین چیز که دیده
df.convert_dtypes().dtypes

# %%
# یه روش اینه
df["Area"] = pd.to_numeric(df["Area"])

# %%
# روش سوم
df[['Area']] = df[['Area']].astype(float)

# %%
# ایا میشه دسته بندی کرد به چندتا دیتافریم 
# مثلا بگرده اونا که استاد معین هستند را در یک دیتا فریم. اونا که پونک هستند یک دیتا فریم و به همین ترتیب

# %%
# برش زدن دیتا فریم ها
# ستون ها

#loc[] syntax to slice columns
df.loc[:,start:stop:step]

# Below are quick example
# Using loc[] to take column slices
# Slice selected multiple columns
df2=df.loc[:, ["Courses","Fee","Duration"]]

# Slice random selected columns
df2=df.loc[:, ["Courses","Fee","Discount"]]

# Slice columns by range
df2=df.loc[:,'Fee':'Discount']
df2=df.loc[:,'Duration':]
df2=df.loc[:,:'Duration']

# slice every alternate column
df2 = df.loc[:,::2]

# Using iloc[] to take column slices
# Slice by selected column position
df2 = df.iloc[:,[1,3,4]]

# Slice between indexes 1 and 4 (2,3,4)
df2 = df.iloc[:,1:4]

# Slice From 3rd to end
df2 = df.iloc[:,2:]

# Slice First Two Columns
df2 = df.iloc[:,:2]

# %%
df1=pd.read_csv('E:/.python and every thing/files/csv files/car-truecat/car_kharegi12.csv',delimiter=',',index_col=None)
df1
# Out:
#       index             model car    money          miles
# 0         0    2020 Nissan Sentra  $18,995  107,319 miles
# 1         1    2015 Dodge Charger  $18,946   24,744 miles
# 2         2     2015 BMW 3 Series  $17,700   69,925 miles
# 3         3  2014 MINI Countryman  $12,997   13,605 miles
# 4         4    2021 Ford Explorer  $33,991  123,460 miles
# ...     ...                   ...      ...            ...
# 3187   3585   2012 Subaru Tribeca   $8,999   24,744 miles
# 3188   3586      2013 Honda Civic  $13,799   25,134 miles
# 3189   3587     2021 Ford Mustang  $25,998   55,257 miles
# 3190   3588   2018 Hyundai Sonata  $14,898   98,078 miles
# 3191   3589    2017 Toyota Tacoma  $15,995  123,460 miles
#
# [3192 rows x 4 columns]

# %%
df1.columns=[c.replace(' ','_') for c in df1.columns]

# %%
df1
# Out:
#       index             model_car    money          miles
# 0         0    2020 Nissan Sentra  $18,995  107,319 miles
# 1         1    2015 Dodge Charger  $18,946   24,744 miles
# 2         2     2015 BMW 3 Series  $17,700   69,925 miles
# 3         3  2014 MINI Countryman  $12,997   13,605 miles
# 4         4    2021 Ford Explorer  $33,991  123,460 miles
# ...     ...                   ...      ...            ...
# 3187   3585   2012 Subaru Tribeca   $8,999   24,744 miles
# 3188   3586      2013 Honda Civic  $13,799   25,134 miles
# 3189   3587     2021 Ford Mustang  $25,998   55,257 miles
# 3190   3588   2018 Hyundai Sonata  $14,898   98,078 miles
# 3191   3589    2017 Toyota Tacoma  $15,995  123,460 miles
#
# [3192 rows x 4 columns]

# %%
df1
# Out:
#       index             model_car    money          miles
# 0         0    2020 Nissan Sentra  $18,995  107,319 miles
# 1         1    2015 Dodge Charger  $18,946   24,744 miles
# 2         2     2015 BMW 3 Series  $17,700   69,925 miles
# 3         3  2014 MINI Countryman  $12,997   13,605 miles
# 4         4    2021 Ford Explorer  $33,991  123,460 miles
# ...     ...                   ...      ...            ...
# 3187   3585   2012 Subaru Tribeca   $8,999   24,744 miles
# 3188   3586      2013 Honda Civic  $13,799   25,134 miles
# 3189   3587     2021 Ford Mustang  $25,998   55,257 miles
# 3190   3588   2018 Hyundai Sonata  $14,898   98,078 miles
# 3191   3589    2017 Toyota Tacoma  $15,995  123,460 miles
#
# [3192 rows x 4 columns]

# %%
# میخوم جدا درستشون کنم
# دوتا یعنی به دتا تقسیمش کن
df1[['Year', 'Brand','Model']] = df1['model_car'].str.split(' ', 2, expand=True)
df1

# اورده یه جدولشو ولی اونو نساخت جدا
# Out:
# C:\Users\محمد نامجو\AppData\Local\Temp\ipykernel_6308\2874794166.py:3: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df1[['Year', 'Brand','Model']] = df1['model_car'].str.split(' ', 2, expand=True)
#       index             model_car    money          miles  Year    Brand  \
# 0         0    2020 Nissan Sentra  $18,995  107,319 miles  2020   Nissan
# 1         1    2015 Dodge Charger  $18,946   24,744 miles  2015    Dodge
# 2         2     2015 BMW 3 Series  $17,700   69,925 miles  2015      BMW
# 3         3  2014 MINI Countryman  $12,997   13,605 miles  2014     MINI
# 4         4    2021 Ford Explorer  $33,991  123,460 miles  2021     Ford
# ...     ...                   ...      ...            ...   ...      ...
# 3187   3585   2012 Subaru Tribeca   $8,999   24,744 miles  2012   Subaru
# 3188   3586      2013 Honda Civic  $13,799   25,134 miles  2013    Honda
# ...

# %%
# این کل سطرو حذف میکنه
df2 = df1.drop(df1.index, axis=0)
df2
# Out:
# Empty DataFrame
# Columns: [index, model_car, money, miles, Year, Model, Brand]
# Index: []

# %%
# df1 = df1.drop(columns=['column_nameA', 'column_nameB'])
df1=df1.drop(columns=['model_car','index'])
df1
# Out:
#         money          miles  Year    Brand       Model
# 0     $18,995  107,319 miles  2020   Nissan      Sentra
# 1     $18,946   24,744 miles  2015    Dodge     Charger
# 2     $17,700   69,925 miles  2015      BMW    3 Series
# 3     $12,997   13,605 miles  2014     MINI  Countryman
# 4     $33,991  123,460 miles  2021     Ford    Explorer
# ...       ...            ...   ...      ...         ...
# 3187   $8,999   24,744 miles  2012   Subaru     Tribeca
# 3188  $13,799   25,134 miles  2013    Honda       Civic
# 3189  $25,998   55,257 miles  2021     Ford     Mustang
# 3190  $14,898   98,078 miles  2018  Hyundai      Sonata
# 3191  $15,995  123,460 miles  2017   Toyota      Tacoma
#
# [3192 rows x 5 columns]

# %%
df1
# Out:
#         money          miles  Year    Brand       Model
# 0     $18,995  107,319 miles  2020   Nissan      Sentra
# 1     $18,946   24,744 miles  2015    Dodge     Charger
# 2     $17,700   69,925 miles  2015      BMW    3 Series
# 3     $12,997   13,605 miles  2014     MINI  Countryman
# 4     $33,991  123,460 miles  2021     Ford    Explorer
# ...       ...            ...   ...      ...         ...
# 3187   $8,999   24,744 miles  2012   Subaru     Tribeca
# 3188  $13,799   25,134 miles  2013    Honda       Civic
# 3189  $25,998   55,257 miles  2021     Ford     Mustang
# 3190  $14,898   98,078 miles  2018  Hyundai      Sonata
# 3191  $15,995  123,460 miles  2017   Toyota      Tacoma
#
# [3192 rows x 5 columns]

# %%
df1.to_csv('E:/.python and every thing/files/csv files/car-truecat/car_kharegi13.csv',index=False)
df1
# Out:
#         money          miles  Year    Brand       Model
# 0     $18,995  107,319 miles  2020   Nissan      Sentra
# 1     $18,946   24,744 miles  2015    Dodge     Charger
# 2     $17,700   69,925 miles  2015      BMW    3 Series
# 3     $12,997   13,605 miles  2014     MINI  Countryman
# 4     $33,991  123,460 miles  2021     Ford    Explorer
# ...       ...            ...   ...      ...         ...
# 3187   $8,999   24,744 miles  2012   Subaru     Tribeca
# 3188  $13,799   25,134 miles  2013    Honda       Civic
# 3189  $25,998   55,257 miles  2021     Ford     Mustang
# 3190  $14,898   98,078 miles  2018  Hyundai      Sonata
# 3191  $15,995  123,460 miles  2017   Toyota      Tacoma
#
# [3192 rows x 5 columns]

# %%
df=pd.read_csv('E:/.python and every thing/files/csv files/car-truecat/car_kharegi13.csv')
df
# Out:
#         money          miles  Year    Brand       Model
# 0     $18,995  107,319 miles  2020   Nissan      Sentra
# 1     $18,946   24,744 miles  2015    Dodge     Charger
# 2     $17,700   69,925 miles  2015      BMW    3 Series
# 3     $12,997   13,605 miles  2014     MINI  Countryman
# 4     $33,991  123,460 miles  2021     Ford    Explorer
# ...       ...            ...   ...      ...         ...
# 3187   $8,999   24,744 miles  2012   Subaru     Tribeca
# 3188  $13,799   25,134 miles  2013    Honda       Civic
# 3189  $25,998   55,257 miles  2021     Ford     Mustang
# 3190  $14,898   98,078 miles  2018  Hyundai      Sonata
# 3191  $15,995  123,460 miles  2017   Toyota      Tacoma
#
# [3192 rows x 5 columns]

# %%
# حالا باید واژه دلار و واژه مایلشو از همه ستون هاش حذف کنم
df['miles'] = df['miles'].map(lambda x: x.lstrip('').rstrip(' miles'))

df
# Out:
#         money    miles  Year    Brand       Model
# 0     $18,995  107,319  2020   Nissan      Sentra
# 1     $18,946   24,744  2015    Dodge     Charger
# 2     $17,700   69,925  2015      BMW    3 Series
# 3     $12,997   13,605  2014     MINI  Countryman
# 4     $33,991  123,460  2021     Ford    Explorer
# ...       ...      ...   ...      ...         ...
# 3187   $8,999   24,744  2012   Subaru     Tribeca
# 3188  $13,799   25,134  2013    Honda       Civic
# 3189  $25,998   55,257  2021     Ford     Mustang
# 3190  $14,898   98,078  2018  Hyundai      Sonata
# 3191  $15,995  123,460  2017   Toyota      Tacoma
#
# [3192 rows x 5 columns]

# %%
df['money']=df['money'].map(lambda x:x.lstrip('$').rstrip(''))
df
# Out:
#        money    miles  Year    Brand       Model
# 0     18,995  107,319  2020   Nissan      Sentra
# 1     18,946   24,744  2015    Dodge     Charger
# 2     17,700   69,925  2015      BMW    3 Series
# 3     12,997   13,605  2014     MINI  Countryman
# 4     33,991  123,460  2021     Ford    Explorer
# ...      ...      ...   ...      ...         ...
# 3187   8,999   24,744  2012   Subaru     Tribeca
# 3188  13,799   25,134  2013    Honda       Civic
# 3189  25,998   55,257  2021     Ford     Mustang
# 3190  14,898   98,078  2018  Hyundai      Sonata
# 3191  15,995  123,460  2017   Toyota      Tacoma
#
# [3192 rows x 5 columns]

# %%
df
# Out:
#        money    miles  Year    Brand       Model
# 0     18,995  107,319  2020   Nissan      Sentra
# 1     18,946   24,744  2015    Dodge     Charger
# 2     17,700   69,925  2015      BMW    3 Series
# 3     12,997   13,605  2014     MINI  Countryman
# 4     33,991  123,460  2021     Ford    Explorer
# ...      ...      ...   ...      ...         ...
# 3187   8,999   24,744  2012   Subaru     Tribeca
# 3188  13,799   25,134  2013    Honda       Civic
# 3189  25,998   55,257  2021     Ford     Mustang
# 3190  14,898   98,078  2018  Hyundai      Sonata
# 3191  15,995  123,460  2017   Toyota      Tacoma
#
# [3192 rows x 5 columns]

# %%
# جابجایی سرستون ها با هم
df = df[['Brand', 'Model', 'Year', 'miles', 'money']]
df
# Out:
#         Brand       Model  Year    miles   money
# 0      Nissan      Sentra  2020  107,319  18,995
# 1       Dodge     Charger  2015   24,744  18,946
# 2         BMW    3 Series  2015   69,925  17,700
# 3        MINI  Countryman  2014   13,605  12,997
# 4        Ford    Explorer  2021  123,460  33,991
# ...       ...         ...   ...      ...     ...
# 3187   Subaru     Tribeca  2012   24,744   8,999
# 3188    Honda       Civic  2013   25,134  13,799
# 3189     Ford     Mustang  2021   55,257  25,998
# 3190  Hyundai      Sonata  2018   98,078  14,898
# 3191   Toyota      Tacoma  2017  123,460  15,995
#
# [3192 rows x 5 columns]

# %%
df.to_csv('E:/.python and every thing/files/csv files/car-truecat/car_kharegi14.csv',index=False)
df
# Out:
#         Brand       Model  Year    miles   money
# 0      Nissan      Sentra  2020  107,319  18,995
# 1       Dodge     Charger  2015   24,744  18,946
# 2         BMW    3 Series  2015   69,925  17,700
# 3        MINI  Countryman  2014   13,605  12,997
# 4        Ford    Explorer  2021  123,460  33,991
# ...       ...         ...   ...      ...     ...
# 3187   Subaru     Tribeca  2012   24,744   8,999
# 3188    Honda       Civic  2013   25,134  13,799
# 3189     Ford     Mustang  2021   55,257  25,998
# 3190  Hyundai      Sonata  2018   98,078  14,898
# 3191   Toyota      Tacoma  2017  123,460  15,995
#
# [3192 rows x 5 columns]

# %%
# نال ها را برداشتن
# خالی هایی یک ستون را برداشتن

import csv
import pandas as pd
import numpy as np

filename='E:/.python and every thing/files/csv files/jadi/weather-stations20140101-20141231.csv'

#Read csv
pdf = pd.read_csv(filename)
pdf.head(5)

pdf = pdf[pd.notnull(pdf["Tm"])]
pdf = pdf.reset_index(drop=True)
pdf.head(5)

# نال هایی که در اون ستون هستش
pdf = pdf[pd.notnull(pdf["Tm"])]
pdf = pdf.reset_index(drop=True)
pdf.head(5)

# %%
# اینم همه ستون هایی که خالی هستند را میده
df_all=df[pd.notnull(df[[]])]
df_all
